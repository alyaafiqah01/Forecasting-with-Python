# %%
import pandas as pd

# %%
data = {
    'Date': ['2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01',
             '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
             '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01'],
    'Parcel Volume': [1000, 900, 1100, 1300, 1500, 1700, 1900, 1800, 1400, 1200,
                      1000, 900, 1100, 1000, 1200],
    'Transportation Costs': [5000, 4500, 5500, 6000, 6500, 7000, 7500, 8000, 6500, 6000,
                             5500, 5000, 5500, 5000, 6000],
    'Inventory Levels': [5000, 5500, 4500, 6000, 6500, 7000, 7500, 8000, 8500, 7000,
                         6500, 6000, 5500, 5000, 6000],
    'Delivery Times': [2, 3, 2, 3, 4, 5, 4, 3, 4, 3, 2, 1, 2, 1, 2],
    'Supply Chain Visibility': [3, 2, 4, 3, 4, 3, 2, 3, 4, 2, 3, 2, 4, 3, 4],
    'Infrastructure': [4, 3, 4, 3, 2, 3, 4, 3, 2, 3, 4, 3, 4, 3, 2]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#           Date  Parcel Volume  Transportation Costs  Inventory Levels  \
# 0   2017-01-01           1000                  5000              5000
# 1   2017-02-01            900                  4500              5500
# 2   2017-03-01           1100                  5500              4500
# 3   2017-04-01           1300                  6000              6000
# 4   2017-05-01           1500                  6500              6500
# 5   2017-06-01           1700                  7000              7000
# 6   2017-07-01           1900                  7500              7500
# 7   2017-08-01           1800                  8000              8000
# 8   2017-09-01           1400                  6500              8500
# 9   2017-10-01           1200                  6000              7000
# 10  2017-11-01           1000                  5500              6500
# 11  2017-12-01            900                  5000              6000
# ...

# %%
df.describe()
# Out:
#        Parcel Volume  Transportation Costs  Inventory Levels  Delivery Times  \
# count      15.000000             15.000000         15.000000       15.000000
# mean     1266.666667           5966.666667       6300.000000        2.733333
# std       326.598632            990.430402       1146.423008        1.162919
# min       900.000000           4500.000000       4500.000000        1.000000
# 25%      1000.000000           5250.000000       5500.000000        2.000000
# 50%      1200.000000           6000.000000       6000.000000        3.000000
# 75%      1450.000000           6500.000000       7000.000000        3.500000
# max      1900.000000           8000.000000       8500.000000        5.000000
#
#        Supply Chain Visibility  Infrastructure
# count                15.000000       15.000000
# mean                  3.066667        3.133333
# std                   0.798809        0.743223
# min                   2.000000        2.000000
# ...

# %%
df.head(3)
# Out:
#          Date  Parcel Volume  Transportation Costs  Inventory Levels  \
# 0  2017-01-01           1000                  5000              5000
# 1  2017-02-01            900                  4500              5500
# 2  2017-03-01           1100                  5500              4500
#
#    Delivery Times  Supply Chain Visibility  Infrastructure
# 0               2                        3               4
# 1               3                        2               3
# 2               2                        4               4

# %%
df.tail(3)
# Out:
#           Date  Parcel Volume  Transportation Costs  Inventory Levels  \
# 12  2018-01-01           1100                  5500              5500
# 13  2018-02-01           1000                  5000              5000
# 14  2018-03-01           1200                  6000              6000
#
#     Delivery Times  Supply Chain Visibility  Infrastructure
# 12               2                        4               4
# 13               1                        3               3
# 14               2                        4               2

# %%
df.to_csv('Overall Data.csv',index=False)

# %%
import matplotlib.pyplot as plt

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
plt.figure(figsize=(10,6))

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Date'],data['Parcel Volume'],marker='o',linestyle='-',color='b',label='Parcel Volume')
plt.xlabel('Date')
plt.ylabel('Parcel Volume')
plt.title('Parcel Volume Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting all metrics on a single multivariate time series plot
plt.figure(figsize=(12, 8))

# Plot each column
for column in df.columns[1:]:  # Skip the 'Date' column
    plt.plot(data['Date'], data[column], marker='o', linestyle='-', label=column)

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Multivariate Time Series Plot')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create DataFrames for the scales
delivery_times = pd.DataFrame({
    'Rating': range(1, 6),
    'Meaning': [
        'Very Fast',
        'Fast',
        'Average',
        'Slow',
        'Very Slow'
    ]
})

supply_chain_visibility = pd.DataFrame({
    'Rating': range(1, 6),
    'Meaning': [
        'Very Low Visibility',
        'Low Visibility',
        'Moderate Visibility',
        'High Visibility',
        'Very High Visibility'
    ]
})

# %%
import seaborn as sns
fig, (ax1,ax2) = plt.subplots(2,1, figsize=(10,12))
# Plot for Delivery Times
sns.barplot(x='Rating', y='Meaning', data=delivery_times, ax=ax1, palette='YlOrRd')
ax1.set_title('Delivery Times Scale')
ax1.set_xlabel('Rating')
ax1.set_ylabel('Meaning')

# Plot for Supply Chain Visibility
sns.barplot(x='Rating', y='Meaning', data=supply_chain_visibility, ax=ax2, palette='YlGnBu')
ax2.set_title('Supply Chain Visibility Scale')
ax2.set_xlabel('Rating')
ax2.set_ylabel('Meaning')

plt.tight_layout()
plt.savefig('rating_scales.png')
print("The rating scales have been saved as 'rating_scales.png'")

# Display the DataFrames
print("\
Delivery Times Scale:")
print(delivery_times.to_string(index=False))

print("\
Supply Chain Visibility Scale:")
print(supply_chain_visibility.to_string(index=False))
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8676\2105369404.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rating', y='Meaning', data=delivery_times, ax=ax1, palette='YlOrRd')
# C:\Users\admin\AppData\Local\Temp\ipykernel_8676\2105369404.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rating', y='Meaning', data=supply_chain_visibility, ax=ax2, palette='YlGnBu')
# The rating scales have been saved as 'rating_scales.png'
# Delivery Times Scale:
#  Rating   Meaning
#       1 Very Fast
#       2      Fast
#       3   Average
#       4      Slow
#       5 Very Slow
# Supply Chain Visibility Scale:
#  Rating              Meaning
#       1  Very Low Visibility
# ...
